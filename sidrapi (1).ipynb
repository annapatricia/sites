# %%
# Instale a biblioteca sidrapy apenas no terminal ou no início do notebook, fora do código Python:
# !pip install -U sidrapy

import pandas as pd
import sidrapy
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings("ignore")  # Linha corrigida
# Out:
# Collecting sidrapy
#   Downloading sidrapy-0.1.4-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from sidrapy) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from sidrapy) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->sidrapy) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->sidrapy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->sidrapy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->sidrapy) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->sidrapy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->sidrapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->sidrapy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->sidrapy) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->sidrapy) (1.16.0)
# Downloading sidrapy-0.1.4-py3-none-any.whl (6.9 kB)
# Installing collected packages: sidrapy
# Successfully installed sidrapy-0.1.4

# %%
# Dados da CNT - Contas nacionais trimestrais

# PIB  e FBCF a valor de mercado com ajuste sazonal
#https://apisidra.ibge.gov.br/values/t/1621/n1/all/v/all/p/all/c11255/90707,93406/d/v584%201

df_cnt = sidrapy.get_table(
    table_code='1621',
    territorial_level="1",
    ibge_territorial_code="all",
    variable="584",
    period="all",
    classifications={'11255': '90707,93406'},
    header='n'
)
df_cnt
# Out:
#     NC      NN  MC             MN       V D1C     D1N     D2C  \
# 0    1  Brasil  30  Número-índice   99.40   1  Brasil  199601
# 1    1  Brasil  30  Número-índice   96.84   1  Brasil  199601
# 2    1  Brasil  30  Número-índice  100.66   1  Brasil  199602
# 3    1  Brasil  30  Número-índice   98.71   1  Brasil  199602
# 4    1  Brasil  30  Número-índice  104.15   1  Brasil  199603
# ..  ..     ...  ..            ...     ...  ..     ...     ...
# 225  1  Brasil  30  Número-índice  171.35   1  Brasil  202401
# 226  1  Brasil  30  Número-índice  189.41   1  Brasil  202402
# 227  1  Brasil  30  Número-índice  175.07   1  Brasil  202402
# 228  1  Brasil  30  Número-índice  191.14   1  Brasil  202403
# 229  1  Brasil  30  Número-índice  178.69   1  Brasil  202403
#
#                    D2N  D3C  \
# 0    1º trimestre 1996  584
# 1    1º trimestre 1996  584
# 2    2º trimestre 1996  584
# 3    2º trimestre 1996  584
# 4    3º trimestre 1996  584
# ..                 ...  ...
# 225  1º trimestre 2024  584
# 226  2º trimestre 2024  584
# 227  2º trimestre 2024  584
# 228  3º trimestre 2024  584
# 229  3º trimestre 2024  584
#
#                                                    D3N    D4C  \
# 0    Série encadeada do índice de volume trimestral...  90707
# 1    Série encadeada do índice de volume trimestral...  93406
# 2    Série encadeada do índice de volume trimestral...  90707
# 3    Série encadeada do índice de volume trimestral...  93406
# 4    Série encadeada do índice de volume trimestral...  90707
# ..                                                 ...    ...
# 225  Série encadeada do índice de volume trimestral...  93406
# 226  Série encadeada do índice de volume trimestral...  90707
# 227  Série encadeada do índice de volume trimestral...  93406
# 228  Série encadeada do índice de volume trimestral...  90707
# 229  Série encadeada do índice de volume trimestral...  93406
#
#                                 D4N
# 0           PIB a preços de mercado
# 1    Formação bruta de capital fixo
# 2           PIB a preços de mercado
# 3    Formação bruta de capital fixo
# 4           PIB a preços de mercado
# ..                              ...
# 225  Formação bruta de capital fixo
# 226         PIB a preços de mercado
# 227  Formação bruta de capital fixo
# 228         PIB a preços de mercado
# 229  Formação bruta de capital fixo
#
# [230 rows x 13 columns]

# %%
# Taxa de investimento - CNT contas nacionais
#https://apisidra.ibge.gov.br/values/t/6727/n1/all/v/all/p/all/d/v2517%201
df_inv = sidrapy.get_table(
    table_code='6727',
    territorial_level = "1",
    ibge_territorial_code = "all",
    variable="2517",
    period = "all",
    header='n')
df_inv
# Out:
#     NC      NN MC MN     V D1C     D1N     D2C                D2N   D3C  \
# 0    1  Brasil  2  %  18.7   1  Brasil  199601  1º trimestre 1996  2517
# 1    1  Brasil  2  %  19.2   1  Brasil  199602  2º trimestre 1996  2517
# 2    1  Brasil  2  %  18.7   1  Brasil  199603  3º trimestre 1996  2517
# 3    1  Brasil  2  %  18.0   1  Brasil  199604  4º trimestre 1996  2517
# 4    1  Brasil  2  %  19.5   1  Brasil  199701  1º trimestre 1997  2517
# ..  ..     ... .. ..   ...  ..     ...     ...                ...   ...
# 110  1  Brasil  2  %  16.4   1  Brasil  202303  3º trimestre 2023  2517
# 111  1  Brasil  2  %  15.9   1  Brasil  202304  4º trimestre 2023  2517
# 112  1  Brasil  2  %  16.7   1  Brasil  202401  1º trimestre 2024  2517
# 113  1  Brasil  2  %  16.6   1  Brasil  202402  2º trimestre 2024  2517
# 114  1  Brasil  2  %  17.6   1  Brasil  202403  3º trimestre 2024  2517
#
#                       D3N
# 0    Taxa de investimento
# 1    Taxa de investimento
# 2    Taxa de investimento
# 3    Taxa de investimento
# 4    Taxa de investimento
# ..                    ...
# 110  Taxa de investimento
# 111  Taxa de investimento
# 112  Taxa de investimento
# 113  Taxa de investimento
# 114  Taxa de investimento
#
# [115 rows x 11 columns]

# %%
# Taxa de investimento - CNT contas nacionais
#https://apisidra.ibge.gov.br/values/t/6727/n1/all/v/all/p/all/d/v2517%201
df_inv = sidrapy.get_table(
    table_code='6727',
    territorial_level = "1",
    ibge_territorial_code = "all",
    variable="2517",
    period = "all",
    header='n')
df_inv
# Out:
#     NC      NN MC MN     V D1C     D1N     D2C                D2N   D3C  \
# 0    1  Brasil  2  %  18.7   1  Brasil  199601  1º trimestre 1996  2517
# 1    1  Brasil  2  %  19.2   1  Brasil  199602  2º trimestre 1996  2517
# 2    1  Brasil  2  %  18.7   1  Brasil  199603  3º trimestre 1996  2517
# 3    1  Brasil  2  %  18.0   1  Brasil  199604  4º trimestre 1996  2517
# 4    1  Brasil  2  %  19.5   1  Brasil  199701  1º trimestre 1997  2517
# ..  ..     ... .. ..   ...  ..     ...     ...                ...   ...
# 110  1  Brasil  2  %  16.4   1  Brasil  202303  3º trimestre 2023  2517
# 111  1  Brasil  2  %  15.9   1  Brasil  202304  4º trimestre 2023  2517
# 112  1  Brasil  2  %  16.7   1  Brasil  202401  1º trimestre 2024  2517
# 113  1  Brasil  2  %  16.6   1  Brasil  202402  2º trimestre 2024  2517
# 114  1  Brasil  2  %  17.6   1  Brasil  202403  3º trimestre 2024  2517
#
#                       D3N
# 0    Taxa de investimento
# 1    Taxa de investimento
# 2    Taxa de investimento
# 3    Taxa de investimento
# 4    Taxa de investimento
# ..                    ...
# 110  Taxa de investimento
# 111  Taxa de investimento
# 112  Taxa de investimento
# 113  Taxa de investimento
# 114  Taxa de investimento
#
# [115 rows x 11 columns]
